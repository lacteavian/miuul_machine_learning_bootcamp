# %% [markdown]
# <a href="https://colab.research.google.com/github/lacteavian/miuul_machine_learning_bootcamp/blob/main/week2_case_study1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df["sex"].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df["pclass"].nunique()
# Out:
# 3

# %%
df[["pclass","parch"]].nunique()
# Out:
# pclass    3
# parch     7
# dtype: int64

# %%
df["embarked"].dtypes
# Out:
# dtype('O')

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df = df.astype({"embarked":"category"})

# %%
df["embarked"].dtypes
# Out:
# CategoricalDtype(categories=['C', 'Q', 'S'], ordered=False)

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked       category
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
x = 0

# %%
df["C" == df["embarked"]]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# 26          0       3    male   NaN      0      0   7.2250        C   Third
# 30          0       1    male  40.0      0      0  27.7208        C   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
df["S" != df["embarked"]]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
df[(500 < df["fare"]) | (70 < df["age"])]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 96          0       1    male  71.0      0      0   34.6542        C  First
# 116         0       3    male  70.5      0      0    7.7500        Q  Third
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 493         0       1    male  71.0      0      0   49.5042        C  First
# 630         1       1    male  80.0      0      0   30.0000        S  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 851         0       3    male  74.0      0      0    7.7750        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 96     man        True    A    Cherbourg    no   True
# 116    man        True  NaN   Queenstown    no   True
# 258  woman       False  NaN    Cherbourg   yes   True
# 493    man        True  NaN    Cherbourg    no   True
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.drop("who", axis=1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
df["deck"].fillna(df['deck'].mode()[0])
# Out:
# 0      C
# 1      C
# 2      C
# 3      C
# 4      C
#       ..
# 886    C
# 887    B
# 888    C
# 889    C
# 890    C
# Name: deck, Length: 891, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
df["age"].fillna(df['age'].median())
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df.groupby(["sex","pclass"]).agg({"survived": ["sum","count","mean"]})
# Out:
#               survived
#                    sum count      mean
# sex    pclass
# female 1            91    94  0.968085
#        2            70    76  0.921053
#        3            72   144  0.500000
# male   1            45   122  0.368852
#        2            17   108  0.157407
#        3            47   347  0.135447

# %%
df["age_flag"]=[1 if 30 > x else 0 for x in df["age"]]

# %%
df["age_flag"]
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 886    1
# 887    1
# 888    0
# 889    1
# 890    0
# Name: age_flag, Length: 891, dtype: int64

# %%
df = sns.load_dataset("tips")

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.groupby("time").agg({"total_bill": ["min","max","mean"]})
# Out:
#        total_bill
#               min    max       mean
# time
# Lunch        7.51  43.11  17.168676
# Dinner       3.07  50.81  20.797159

# %%
df.groupby(["day","time"]).agg({"total_bill": ["min","max","mean"]})
# Out:
#             total_bill
#                    min    max       mean
# day  time
# Thur Lunch        7.51  43.11  17.664754
#      Dinner      18.78  18.78  18.780000
# Fri  Lunch        8.58  16.27  12.845714
#      Dinner       5.75  40.17  19.663333
# Sat  Lunch         NaN    NaN        NaN
#      Dinner       3.07  50.81  20.441379
# Sun  Lunch         NaN    NaN        NaN
#      Dinner       7.25  48.17  21.410000

# %%
new_df.groupby(["sex","time"]).agg({"total_bill": ["min","max","mean"],"tip": ["min","max","mean"]})
# Out:
#               total_bill                     tip
#                      min    max       mean   min   max      mean
# sex    time
# Male   Lunch         NaN    NaN        NaN   NaN   NaN       NaN
#        Dinner        NaN    NaN        NaN   NaN   NaN       NaN
# Female Lunch        8.35  43.11  16.339143  1.25  5.17  2.582857
#        Dinner        NaN    NaN        NaN   NaN   NaN       NaN

# %%
df.loc[:,["size","total_bill"]][(df["size"] < 3) & (df["total_bill"] > 10)].mean()
# Out:
# size           1.993007
# total_bill    17.184965
# dtype: float64

# %%
df["total_bill_tip_sum"] = df["total_bill"] + df["tip"]

# %%
new_df = df["total_bill_tip_sum"].sort_values(ascending=False).head(30)

# %%
new_df
# Out:
# 170    60.81
# 212    57.33
# 59     55.00
# 156    53.17
# 182    48.85
# 197    48.11
# 23     47.00
# 102    46.80
# 142    46.19
# 95     44.90
# 184    43.55
# 112    42.07
# 207    41.73
# 56     41.01
# 141    41.00
# 238    40.50
# 11     40.26
# 52     40.01
# 85     40.00
# 47     38.40
# 180    38.33
# 179    38.18
# 83     37.68
# 39     36.27
# 167    36.21
# 175    36.01
# 44     36.00
# 173    35.03
# 116    35.00
# 155    34.99
# Name: total_bill_tip_sum, dtype: float64
